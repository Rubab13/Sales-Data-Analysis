# %% [markdown]
# <h1 style='color:#1e555c;font-weight:bold;text-align:center;font-size:3rem;'>Sales</h1>

# %% [markdown]
# <div>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Importing Libraries</h2>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno
import numpy as np
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_6716\1766445200.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# <div>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Importing Dataset</h2>
# </div>

# %%
data = pd.read_csv('sales_data_sample.csv',encoding='latin1')

# %% [markdown]
# <div>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>This is our Dataset</h2>
# </div>

# %%
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %% [markdown]
# <div>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Number of columns and rows</h2>
# </div>

# %%
data.shape
# Out:
# (2823, 25)

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>2823 Rows & 25 Columns</p>
# </div>

# %% [markdown]
# <div>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>The dataset contains the following columns</h2>
# </div>

# %%
data.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
for col in data.columns:
    print(col)
# Out:
# ORDERNUMBER
# QUANTITYORDERED
# PRICEEACH
# ORDERLINENUMBER
# SALES
# ORDERDATE
# STATUS
# QTR_ID
# MONTH_ID
# YEAR_ID
# PRODUCTLINE
# MSRP
# PRODUCTCODE
# CUSTOMERNAME
# PHONE
# ADDRESSLINE1
# ADDRESSLINE2
# CITY
# STATE
# POSTALCODE
# COUNTRY
# TERRITORY
# CONTACTLASTNAME
# CONTACTFIRSTNAME
# DEALSIZE

# %% [markdown]
# <div>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Looking for Null values in the data</h2>
# </div>

# %%
data.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>4 columns contain NULL values: ADDRESSLINE2, STATE, POSTALCODE, TERRITORY</p>
# </div>

# %% [markdown]
# <div>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Visualizing Null values</h2>
# </div>

# %%
missingno.bar(data, figsize=(13,8), fontsize=7, color='#f9c784');

# %%
((data.isnull().sum())/data.shape[0])*100
# Out:
# ORDERNUMBER          0.000000
# QUANTITYORDERED      0.000000
# PRICEEACH            0.000000
# ORDERLINENUMBER      0.000000
# SALES                0.000000
# ORDERDATE            0.000000
# STATUS               0.000000
# QTR_ID               0.000000
# MONTH_ID             0.000000
# YEAR_ID              0.000000
# PRODUCTLINE          0.000000
# MSRP                 0.000000
# PRODUCTCODE          0.000000
# CUSTOMERNAME         0.000000
# PHONE                0.000000
# ADDRESSLINE1         0.000000
# ADDRESSLINE2        89.302161
# CITY                 0.000000
# STATE               52.639036
# POSTALCODE           2.692171
# COUNTRY              0.000000
# TERRITORY           38.044633
# CONTACTLASTNAME      0.000000
# CONTACTFIRSTNAME     0.000000
# DEALSIZE             0.000000
# dtype: float64

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>The columns with NULL values will be dropped from the data. There are 2% NULL values in the column 'POSTALCODE', so we'll filter out those rows.</p>
# </div>

# %% [markdown]
# <div>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Dropping Columns from the Dataset</h2>
# </div>

# %%
data['TERRITORY'].unique()
# Out:
# array([nan, 'EMEA', 'APAC', 'Japan'], dtype=object)

# %%
data.drop(columns=['STATE', 'ADDRESSLINE2', 'TERRITORY'], inplace=True)

# %%
((data.isnull().sum())/data.shape[0])*100
# Out:
# ORDERNUMBER         0.000000
# QUANTITYORDERED     0.000000
# PRICEEACH           0.000000
# ORDERLINENUMBER     0.000000
# SALES               0.000000
# ORDERDATE           0.000000
# STATUS              0.000000
# QTR_ID              0.000000
# MONTH_ID            0.000000
# YEAR_ID             0.000000
# PRODUCTLINE         0.000000
# MSRP                0.000000
# PRODUCTCODE         0.000000
# CUSTOMERNAME        0.000000
# PHONE               0.000000
# ADDRESSLINE1        0.000000
# CITY                0.000000
# POSTALCODE          2.692171
# COUNTRY             0.000000
# CONTACTLASTNAME     0.000000
# CONTACTFIRSTNAME    0.000000
# DEALSIZE            0.000000
# dtype: float64

# %%
data.dropna(inplace=True)

# %%
((data.isnull().sum())/data.shape[0])*100
# Out:
# ORDERNUMBER         0.0
# QUANTITYORDERED     0.0
# PRICEEACH           0.0
# ORDERLINENUMBER     0.0
# SALES               0.0
# ORDERDATE           0.0
# STATUS              0.0
# QTR_ID              0.0
# MONTH_ID            0.0
# YEAR_ID             0.0
# PRODUCTLINE         0.0
# MSRP                0.0
# PRODUCTCODE         0.0
# CUSTOMERNAME        0.0
# PHONE               0.0
# ADDRESSLINE1        0.0
# CITY                0.0
# POSTALCODE          0.0
# COUNTRY             0.0
# CONTACTLASTNAME     0.0
# CONTACTFIRSTNAME    0.0
# DEALSIZE            0.0
# dtype: float64

# %% [markdown]
# <div>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Checking for Duplicate Values in the Data</h2>
# </div>

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">

# %% [markdown]
# <div style='background-color:#f4d8cd;'>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Time Span of Sales Data</h2>
# </div>

# %%
data['YEAR_ID'].unique()
# Out:
# array([2003, 2004, 2005], dtype=int64)

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>The data spanned over the course of 3 years from 2003 to 2005.</p>
# </div>

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">

# %% [markdown]
# <div style='background-color:#f4d8cd;'>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Year-wise Revenue</h2>
# </div>

# %%
data.groupby(['YEAR_ID'], as_index=False).agg({'SALES':'sum'}).sort_values(by = 'SALES', ascending = False)
# Out:
#    YEAR_ID       SALES
# 1     2004  4669924.56
# 0     2003  3353014.06
# 2     2005  1737283.09

# %%
sns.barplot(x='YEAR_ID', y='SALES', data = data.groupby(['YEAR_ID'], as_index=False).agg({'SALES':'sum'}).sort_values(by = 'SALES', ascending = False), color='#f9c784')
plt.title('Year wise Sales')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>2004 was the most successful year with respect to Revenue/earnings.</p>
# </div>

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">

# %% [markdown]
# <div style='background-color:#f4d8cd;'>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Year Wise Sales</h2>
# </div>

# %%
data.groupby(['YEAR_ID'], as_index=False).agg({'QUANTITYORDERED':'sum'}).sort_values(by = 'QUANTITYORDERED', ascending = False)
# Out:
#    YEAR_ID  QUANTITYORDERED
# 1     2004            46294
# 0     2003            32974
# 2     2005            17160

# %%
sns.barplot(x='YEAR_ID', y='QUANTITYORDERED', data = data.groupby(['YEAR_ID'], as_index=False).agg({'QUANTITYORDERED':'sum'}).sort_values(by = 'QUANTITYORDERED', ascending = False), color='#f9c784')
plt.title('Year wise quantity ordered')
plt.xlabel('Year')
plt.ylabel('Quantity Ordered')
plt.savefig("sdsd")
plt.show()

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>2004 was the most successful year with respect to Sales.</p>
# </div>

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">

# %% [markdown]
# <div style='background-color:#f4d8cd;'>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Year-wise Distribution of Sales of Product Lines</h2>
# </div>

# %%
data.groupby(['YEAR_ID', 'PRODUCTLINE'], as_index=False).agg({'SALES':'sum'}).sort_values(by=['YEAR_ID', 'SALES'], ascending=[True, False])
# Out:
#     YEAR_ID       PRODUCTLINE       SALES
# 0      2003      Classic Cars  1435572.13
# 6      2003      Vintage Cars   599111.59
# 5      2003  Trucks and Buses   420429.93
# 1      2003       Motorcycles   308019.43
# 2      2003            Planes   272257.60
# 3      2003             Ships   244821.09
# 4      2003            Trains    72802.29
# 7      2004      Classic Cars  1754056.17
# 13     2004      Vintage Cars   883685.10
# 8      2004       Motorcycles   560545.23
# 12     2004  Trucks and Buses   522429.94
# 9      2004            Planes   496991.65
# 10     2004             Ships   335692.62
# 11     2004            Trains   116523.85
# 14     2005      Classic Cars   653240.24
# 20     2005      Vintage Cars   323878.99
# 15     2005       Motorcycles   234947.53
# 16     2005            Planes   200074.17
# 19     2005  Trucks and Buses   168699.32
# 17     2005             Ships   119525.51
# 18     2005            Trains    36917.33

# %%
sns.barplot(x='YEAR_ID', y='SALES', data = data.groupby(['YEAR_ID', 'PRODUCTLINE'], as_index=False).agg({'SALES':'sum'}), palette='dark:#f9c784', hue = 'PRODUCTLINE')
plt.title('Year wise Sales')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>Throughout the three years, Classic Cars has performed better.</p>
# </div>

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">

# %% [markdown]
# <div style='background-color:#f4d8cd;'>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Quarter-wise Distribution of Sales of Product Lines</h2>
# </div>

# %%
a = data.groupby(['QTR_ID', 'PRODUCTLINE'], as_index=False).agg({'SALES':'sum'}).sort_values(by='QTR_ID')
a
# Out:
#     QTR_ID       PRODUCTLINE       SALES
# 0        1      Classic Cars   855747.94
# 1        1       Motorcycles   264385.54
# 2        1            Planes   228676.36
# 3        1             Ships   189479.39
# 4        1            Trains    58115.80
# 5        1  Trucks and Buses   199261.34
# 6        1      Vintage Cars   458362.84
# 12       2  Trucks and Buses   240838.42
# 11       2            Trains    35284.87
# 10       2             Ships   143114.28
# 13       2      Vintage Cars   337386.98
# 8        2       Motorcycles   277822.27
# 7        2      Classic Cars   766618.73
# 9        2            Planes   247054.75
# 20       3      Vintage Cars   297935.31
# 18       3            Trains    39450.16
# 17       3             Ships   120498.22
# 19       3  Trucks and Buses   199511.01
# 15       3       Motorcycles   213194.70
# 14       3      Classic Cars   745268.46
# 16       3            Planes   143052.95
# 26       4  Trucks and Buses   471948.42
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=a, x='PRODUCTLINE', y='SALES', hue='QTR_ID', estimator=sum)
plt.title('Sales of Product Lines through Quarters')
plt.xlabel('Product Line')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>There seems to be an increase in sales in the last quarter of the year.</p>
# </div>

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">

# %% [markdown]
# <div style='background-color:#f4d8cd;'>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Which product line generated the highest revenue?</h2>
# </div>

# %%
data['PRODUCTLINE'].unique()
# Out:
# array(['Motorcycles', 'Classic Cars', 'Trucks and Buses', 'Vintage Cars',
#        'Planes', 'Ships', 'Trains'], dtype=object)

# %%
unique_product_lines = data['PRODUCTLINE'].unique()
df_unique_product_lines = pd.DataFrame(unique_product_lines, columns=['Unique_Product_Line'])
print(df_unique_product_lines)
# Out:
#   Unique_Product_Line
# 0         Motorcycles
# 1        Classic Cars
# 2    Trucks and Buses
# 3        Vintage Cars
# 4              Planes
# 5               Ships
# 6              Trains

# %% [markdown]
# There are seven unique product lines. Let analyze their individual sales

# %%
data.groupby('PRODUCTLINE').agg({'SALES':'sum'}).sort_values(by='SALES', ascending=False)
# Out:
#                        SALES
# PRODUCTLINE
# Classic Cars      3842868.54
# Vintage Cars      1806675.68
# Trucks and Buses  1111559.19
# Motorcycles       1103512.19
# Planes             969323.42
# Ships              700039.22
# Trains             226243.47

# %%
plt.figure(figsize=(7, 6))
sns.barplot(x='PRODUCTLINE', y='SALES', data=data.groupby('PRODUCTLINE').agg({'SALES':'sum'}).sort_values(by='SALES', ascending=False), color='#f9c784')
plt.title('Product Line and Sales')
plt.xlabel('PRODUCT LINE')
plt.ylabel('SALES')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>Classic Cars is the most sold product line out of the seven.</p>
# </div>

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">

# %% [markdown]
# <div style='background-color:#f4d8cd;'>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>How do sales vary by geographic location (e.g., city, country)?</h2>
# </div>

# %%
data.groupby(['COUNTRY'], as_index=False).agg({'SALES':'sum'}).sort_values(by = 'SALES', ascending = False).head()
# Out:
#       COUNTRY       SALES
# 18        USA  3355575.69
# 14      Spain  1215686.92
# 6      France  1110916.52
# 0   Australia   630623.10
# 17         UK   478880.46

# %%
sns.barplot(x='COUNTRY', y='SALES', data = data.groupby(['COUNTRY'], as_index=False).agg({'SALES':'sum'}).sort_values(by = 'SALES', ascending = False).head(), color='#f9c784')
plt.title('Top selling countries')
plt.xlabel('Country')
plt.ylabel('SALES')
plt.show()

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>USA is the top selling country.</p>
# </div>

# %%
data.groupby(['COUNTRY', 'CITY'], as_index=False).agg({'SALES':'sum'}).sort_values(by = 'SALES', ascending = False).head()
# Out:
#       COUNTRY        CITY       SALES
# 41      Spain      Madrid  1082551.44
# 69        USA  San Rafael   654858.06
# 60        USA         NYC   560787.77
# 39  Singapore   Singapore   288488.41
# 21     France       Paris   268944.68

# %%
sns.barplot(x='CITY', y='SALES', data = data.groupby(['COUNTRY', 'CITY'], as_index=False).agg({'SALES':'sum'}).sort_values(by = 'SALES', ascending = False).head(), color='#f9c784')
plt.title('Top selling cities')
plt.xlabel('Country')
plt.ylabel('SALES')
plt.savefig("rianns")
plt.show()

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>Madrid is the top selling city.</p>
# </div>

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">

# %% [markdown]
# <div style='background-color:#f4d8cd;'>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>What is the distribution of deal sizes?</h2>
# </div>

# %% [markdown]
# #### Understand the range and variability of deal sizes to inform pricing strategies.

# %%
data['DEALSIZE'].unique()
# Out:
# array(['Small', 'Medium', 'Large'], dtype=object)

# %% [markdown]
# The DEALSIZE column in your dataset represents the size category of the orders. This column categorizes orders into categories such as 'Small', 'Medium', and 'Large'.
#
# #### Examples of DEALSIZE categories:
# Small: Orders with a low total value or quantity. <br>Medium: Orders with a moderate total value or quantity. <br>Large: Orders with a high total value or quantity.
#
# #### Now, I have to find out on what value from the data is deal size dependant upon.

# %%
data.iloc[0]
# Out:
# ORDERNUMBER                           10107
# QUANTITYORDERED                          30
# PRICEEACH                              95.7
# ORDERLINENUMBER                           2
# SALES                                2871.0
# ORDERDATE                    2/24/2003 0:00
# STATUS                              Shipped
# QTR_ID                                    1
# MONTH_ID                                  2
# YEAR_ID                                2003
# PRODUCTLINE                     Motorcycles
# MSRP                                     95
# PRODUCTCODE                        S10_1678
# CUSTOMERNAME              Land of Toys Inc.
# PHONE                            2125557818
# ADDRESSLINE1        897 Long Airport Avenue
# CITY                                    NYC
# POSTALCODE                            10022
# COUNTRY                                 USA
# CONTACTLASTNAME                          Yu
# CONTACTFIRSTNAME                       Kwai
# ...

# %%
data.loc[data['DEALSIZE'] == 'Small'].min()
# Out:
# ORDERNUMBER                         10100
# QUANTITYORDERED                         6
# PRICEEACH                           26.88
# ORDERLINENUMBER                         1
# SALES                              482.13
# ORDERDATE                  1/10/2003 0:00
# STATUS                          Cancelled
# QTR_ID                                  1
# MONTH_ID                                1
# YEAR_ID                              2003
# PRODUCTLINE                  Classic Cars
# MSRP                                   33
# PRODUCTCODE                      S10_1678
# CUSTOMERNAME               AV Stores, Co.
# PHONE                        (02) 5554 67
# ADDRESSLINE1        1 rue Alsace-Lorraine
# CITY                              Aaarhus
# POSTALCODE                          10022
# COUNTRY                         Australia
# CONTACTLASTNAME                   Accorti
# CONTACTFIRSTNAME                   Adrian
# DEALSIZE                            Small
# dtype: object

# %%
data.loc[data['DEALSIZE'] == 'Small'].max()
# Out:
# ORDERNUMBER                     10425
# QUANTITYORDERED                    64
# PRICEEACH                       100.0
# ORDERLINENUMBER                    18
# SALES                         2999.97
# ORDERDATE               9/9/2004 0:00
# STATUS                        Shipped
# QTR_ID                              4
# MONTH_ID                           12
# YEAR_ID                          2005
# PRODUCTLINE              Vintage Cars
# MSRP                              214
# PRODUCTCODE                  S72_3212
# CUSTOMERNAME        giftsbymail.co.uk
# PHONE                      981-443655
# ADDRESSLINE1             Vinb'ltet 34
# CITY                     White Plains
# POSTALCODE                    WX3 6FW
# COUNTRY                           USA
# CONTACTLASTNAME                    Yu
# CONTACTFIRSTNAME                Yoshi
# DEALSIZE                        Small
# dtype: object

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>Check carefully. The Small dealsize is occupies a block of data where sales is more than 0 and less than approximately 3000. Let's check for other dealsizes as well before forming a conclusion about sales.</p>
# </div>

# %%
data.loc[data['DEALSIZE'] == 'Medium'].min()
# Out:
# ORDERNUMBER                         10100
# QUANTITYORDERED                        20
# PRICEEACH                           55.72
# ORDERLINENUMBER                         1
# SALES                              3002.4
# ORDERDATE                  1/10/2003 0:00
# STATUS                          Cancelled
# QTR_ID                                  1
# MONTH_ID                                1
# YEAR_ID                              2003
# PRODUCTLINE                  Classic Cars
# MSRP                                   33
# PRODUCTCODE                      S10_1678
# CUSTOMERNAME               AV Stores, Co.
# PHONE                        (02) 5554 67
# ADDRESSLINE1        1 rue Alsace-Lorraine
# CITY                              Aaarhus
# POSTALCODE                          10022
# COUNTRY                         Australia
# CONTACTLASTNAME                   Accorti
# CONTACTFIRSTNAME                   Adrian
# DEALSIZE                           Medium
# dtype: object

# %%
data.loc[data['DEALSIZE'] == 'Medium'].max()
# Out:
# ORDERNUMBER                     10425
# QUANTITYORDERED                    66
# PRICEEACH                       100.0
# ORDERLINENUMBER                    18
# SALES                         6996.42
# ORDERDATE               9/9/2004 0:00
# STATUS                        Shipped
# QTR_ID                              4
# MONTH_ID                           12
# YEAR_ID                          2005
# PRODUCTLINE              Vintage Cars
# MSRP                              214
# PRODUCTCODE                  S72_3212
# CUSTOMERNAME        giftsbymail.co.uk
# PHONE                      981-443655
# ADDRESSLINE1             Vinb'ltet 34
# CITY                     White Plains
# POSTALCODE                    WX3 6FW
# COUNTRY                           USA
# CONTACTLASTNAME                    Yu
# CONTACTFIRSTNAME                Yoshi
# DEALSIZE                       Medium
# dtype: object

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>Medium lies between 3000 and 7000 approx.</p>
# </div>

# %%
data.loc[data['DEALSIZE'] == 'Large'].min()
# Out:
# ORDERNUMBER                         10105
# QUANTITYORDERED                        29
# PRICEEACH                           88.75
# ORDERLINENUMBER                         1
# SALES                             7016.31
# ORDERDATE                  1/12/2005 0:00
# STATUS                           Disputed
# QTR_ID                                  1
# MONTH_ID                                1
# YEAR_ID                              2003
# PRODUCTLINE                  Classic Cars
# MSRP                                   33
# PRODUCTCODE                      S10_1678
# CUSTOMERNAME               AV Stores, Co.
# PHONE                      (1) 42.34.2555
# ADDRESSLINE1        1 rue Alsace-Lorraine
# CITY                              Aaarhus
# POSTALCODE                          10022
# COUNTRY                         Australia
# CONTACTLASTNAME                   Accorti
# CONTACTFIRSTNAME                   Adrian
# DEALSIZE                            Large
# dtype: object

# %%
data.loc[data['DEALSIZE'] == 'Large'].max()
# Out:
# ORDERNUMBER                            10424
# QUANTITYORDERED                           97
# PRICEEACH                              100.0
# ORDERLINENUMBER                           17
# SALES                                14082.8
# ORDERDATE                      9/9/2004 0:00
# STATUS                               Shipped
# QTR_ID                                     4
# MONTH_ID                                  12
# YEAR_ID                                 2005
# PRODUCTLINE                     Vintage Cars
# MSRP                                     214
# PRODUCTCODE                        S700_3167
# CUSTOMERNAME        Volvo Model Replicas, Co
# PHONE                             981-443655
# ADDRESSLINE1                    Vinb'ltet 34
# CITY                            White Plains
# POSTALCODE                           WX1 6LT
# COUNTRY                                  USA
# CONTACTLASTNAME                           Yu
# CONTACTFIRSTNAME                       Yoshi
# ...

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>And the Large dealsize ranges from 7000 approx. to whatever the maximum value of the sale is.</p>
# </div>

# %%
bar_plot = data['DEALSIZE'].value_counts().plot(kind='bar', color='#f9c784')
plt.title('Deal Size Distribution')
plt.xlabel('Deal Size')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>The giveaway here is that mostly people have ordered product(s) that lie in the Medium Deal Size. To simplify this claim, we would infer that most people have made a purchase ranging between 3000 and 7000 dollars(or whatever the currency is) between the years 2003 to 2005.</p>
# </div>

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">

# %% [markdown]
# <div style='background-color:#f4d8cd;'>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Which customers place the largest orders by quantity and sales value?</h2>
# </div>

# %% [markdown]
# #### Identify high-value customers to target for special promotions or loyalty programs.

# %% [markdown]
# Customers who buy products in bulks

# %%
df = data.sort_values(by='QUANTITYORDERED', ascending=False)
df = df['CUSTOMERNAME'].unique()
df = pd.DataFrame(df, columns=['CUSTOMERNAME']).head()
df
# Out:
#                 CUSTOMERNAME
# 0                Mini Caravy
# 1    Tekni Collectables Inc.
# 2  The Sharp Gifts Warehouse
# 3      Salzburg Collectables
# 4      Euro Shopping Channel

# %% [markdown]
# Customers who have purchased a lot of products with respect to their price

# %%
df = data.sort_values(by='SALES', ascending=False)
df = df['CUSTOMERNAME'].unique()
df = pd.DataFrame(df, columns=['CUSTOMERNAME']).head()
df
# Out:
#                    CUSTOMERNAME
# 0     The Sharp Gifts Warehouse
# 1  Online Diecast Creations Co.
# 2         Euro Shopping Channel
# 3         UK Collectables, Ltd.
# 4                   Mini Caravy

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>Given are two lists of customers. They are important with respect to the business. They are a major source of income, so from a business pov they are to be paid special attention.</p>
# </div>

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">

# %% [markdown]
# <div style='background-color:#f4d8cd;'>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Is there any correlation between product price and sales volume?</h2>
# </div>

# %% [markdown]
# #### Investigate whether higher-priced products tend to sell in larger quantities.

# %%
correlation = np.corrcoef(data['PRICEEACH'], data['QUANTITYORDERED'])[0, 1]
print(f"Correlation coefficient between PRICEEACH and QUANTITYORDERED: {correlation}")
# Out:
# Correlation coefficient between PRICEEACH and QUANTITYORDERED: 0.006670840423682783

# %% [markdown]
# #### A very weak positive correlation
# Since the correlation coefficient is close to zero, it suggests that there is almost no linear relationship between the price of the product and the quantity ordered. In other words, knowing the price of a product does not provide much information about how many units will be sold.
# A positive coefficient indicates that as one variable (price) increases, the other variable (quantity ordered) tends to increase slightly, but the relationship is so weak that it is practically negligible.

# %%
lm = sns.lmplot(x='PRICEEACH', y='QUANTITYORDERED', data=data, aspect=1.5, scatter_kws={'color': '#000', 'alpha': 0.7}, line_kws={'color': 'red'})
lm.set_axis_labels('Price Each', 'Quantity Ordered')
lm.fig.suptitle('Relationship between Price and Sales Volume', y=1.03)
plt.show()

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>The best fit line is horizontal. Almost parallel to the x-axis, which predicts that we cannot make an assumption on the basis of price about the sales. However, a very slight assumption based on the positive sign is this that with the increase of price there is a 1% chance is that sales will increase. The result is people tend to buy cheaper products.</p>
# </div>

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">

# %% [markdown]
# <div style='background-color:#f4d8cd;'>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Are there any seasonal trends in sales?</h2>
# </div>

# %% [markdown]
# #### Explore how sales vary by quarter or month to identify seasonal patterns.

# %%
quarterly_sales = data.groupby(['YEAR_ID', 'QTR_ID'])['SALES'].sum().reset_index()
quarterly_sales
# Out:
#    YEAR_ID  QTR_ID       SALES
# 0     2003       1   426399.11
# 1     2003       2   562365.22
# 2     2003       3   649514.54
# 3     2003       4  1714735.19
# 4     2004       1   809841.36
# 5     2004       2   766260.73
# 6     2004       3  1109396.27
# 7     2004       4  1984426.20
# 8     2005       1  1017788.74
# 9     2005       2   719494.35

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='QTR_ID', y='SALES', hue='YEAR_ID', data=quarterly_sales, marker='o', palette='Set2')
plt.title('Quarterly Sales Trends')
plt.xlabel('Quarter')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>2005 is out of scene. 2004 performed better as we have seen previously.</p>
# </div>

# %%
monthly_sales = data.groupby(['YEAR_ID', 'MONTH_ID'])['SALES'].sum().reset_index()
monthly_sales
# Out:
#     YEAR_ID  MONTH_ID       SALES
# 0      2003         1   129753.60
# 1      2003         2   140836.19
# 2      2003         3   155809.32
# 3      2003         4   201609.55
# 4      2003         5   192673.11
# 5      2003         6   168082.56
# 6      2003         7   187731.88
# 7      2003         8   197809.30
# 8      2003         9   263973.36
# 9      2003        10   448452.95
# 10     2003        11  1029837.66
# 11     2003        12   236444.58
# 12     2004         1   292688.10
# 13     2004         2   311419.53
# 14     2004         3   205733.73
# 15     2004         4   206148.12
# 16     2004         5   273438.39
# 17     2004         6   286674.22
# 18     2004         7   327144.09
# 19     2004         8   461501.27
# 20     2004         9   320750.91
# 21     2004        10   552924.25
# 22     2004        11  1058699.29
# 23     2004        12   372802.66
# 24     2005         1   339543.42
# 25     2005         2   303982.56
# ...

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='MONTH_ID', y='SALES', hue='YEAR_ID', data=monthly_sales, marker='o', palette='deep')
plt.title('Monthly Sales Trends')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>Monthly analysis also gives us the same result. 2004 was the most successful year.</p>
# </div>

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">

# %% [markdown]
# <div style='background-color:#f4d8cd;'>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>Are there regional differences in product preferences?</h2>
# </div>

# %%
country_product_counts = data.groupby(['COUNTRY', 'PRODUCTLINE']).size().reset_index(name='COUNT')
country_product_pivot = country_product_counts.pivot(index='COUNTRY', columns='PRODUCTLINE', values='COUNT').fillna(0)
plt.figure(figsize=(10, 8))
sns.heatmap(country_product_pivot, annot=True, cmap='viridis', fmt='.0f')
plt.title('Product Preferences Across Countries')
plt.xlabel('Product Line')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# #### Lighter shades indicate higher counts, showing which product lines are more popular in specific countries.<br>
# #### Darker shades represent lower counts, indicating less popularity.<br>
# #### The numbers on the heatmap represent the exact count of each product line within each country.

# %% [markdown]
# <div style='background-color:#EAD7D7;'>
#     <p style='color:#1e555c;font-weight:400;font-size:1.3rem;padding:1rem'>As we have seen, Classic Cars were the most popular ones and USA was on the top of the list representing top selling countries. Hence, USA had the most light colloured blocks. Switzerland apparently was the lowest ones with respect to Sales.</p>
# </div>

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">

# %% [markdown]
# <div style='background-color:#f4d8cd;'>
#     <h2 style='color:#1e555c;font-weight:bold;font-size:1.5rem;padding:1rem;'>How does the MSRP (Manufacturer's Suggested Retail Price) compare with actual PRICEEACH?</h2>
# </div>

# %%
data['PRICE_DIFF'] = data['PRICEEACH'] - data['MSRP']
data['PRICE_DIFF_PERCENT'] = ((data['PRICEEACH'] - data['MSRP']) / data['MSRP']) * 100
plt.figure(figsize=(8, 6))
sns.scatterplot(x='MSRP', y='PRICEEACH', data=data, color='b', s=100, alpha=0.8)
plt.plot(data['MSRP'], data['MSRP'], color='r', label='MSRP = PRICEEACH')
plt.title('Comparison of MSRP vs PRICEEACH')
plt.xlabel('MSRP (Manufacturer\'s Suggested Retail Price)')
plt.ylabel('PRICEEACH (Actual Price)')
plt.legend()
plt.show()

# %%
print("\nSummary Statistics:")
print(data[['MSRP', 'PRICEEACH', 'PRICE_DIFF', 'PRICE_DIFF_PERCENT']].describe())
# Out:
# Summary Statistics:
#               MSRP    PRICEEACH   PRICE_DIFF  PRICE_DIFF_PERCENT
# count  2747.000000  2747.000000  2747.000000         2747.000000
# mean    100.691664    83.648966   -17.042697           -9.485719
# std      40.114802    20.144229    30.548512           27.150559
# min      33.000000    26.880000  -154.640000          -77.133803
# 25%      68.000000    68.745000   -28.215000          -24.242424
# 50%      99.000000    95.550000    -9.000000          -12.000000
# 75%     124.000000   100.000000     1.695000            2.746957
# max     214.000000   100.000000    67.000000          203.030303

# %% [markdown]
# <hr style="border-top: 2px solid #333;margin:30px 0;">
